# %%
import billboard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import json
import sys
import math

from bs4 import BeautifulSoup
import requests

from __future__ import division

import argparse

from pychorus.helpers import find_and_output_chorus

import warnings
import os
warnings.filterwarnings('ignore')
from pychorus import find_and_output_chorus

# %%
dataset = pd.read_csv('/home/yamen/Projects/Technocolabs/Billboard.csv')
print(dataset.shape)
titles= list(dataset['Title'])
artists = list(dataset['Artist'])
data = []
# Out:
# (828, 3)

# %%
import os
from requests import get
from yt_dlp import YoutubeDL

filename=[]
def search1(arg):
  # In this search(), I downloaded all popular and unpopular songs in an single folder called mp3
  YDL_OPTIONS = {'outtmpl': f"/home/yamen/Projects/Technocolabs/mp3/{arg}"+'.mp3','format' : 'bestaudio/best', 'noplaylist' : 'True'}
  with YoutubeDL(YDL_OPTIONS) as ydl:
    try:
      get(arg)
    except:
      song =   ydl.extract_info(f"ytsearch:{arg}", download=True)['entries'][0]
    else:
      song =   ydl.extract_info(arg, download=True)

  newpath = f"{arg}"+'.mp3'
  if os.path.isfile(newpath):
    pass
  else:
    filename.append(newpath)
  
  return filename, song

# %%
titles = (dataset.Title + " - " + dataset.Artist).tolist()
# Here I'm Passing songs title and artists name as a title to the above search()
for i,title in enumerate(titles):
     search1(title)
# Out:
# [download] Downloading playlist: Blinding Lights - The Weeknd
# [youtube:search] query "Blinding Lights - The Weeknd": Downloading web client config
# [youtube:search] query "Blinding Lights - The Weeknd" page 1: Downloading API JSON
# [youtube:search] Playlist Blinding Lights - The Weeknd: Downloading 1 videos of 1
# [download] Downloading video 1 of 1
# [youtube] 4NRXx6U8ABQ: Downloading webpage
# [youtube] 4NRXx6U8ABQ: Downloading android player API JSON
# [info] 4NRXx6U8ABQ: Downloading 1 format(s): 251
# [download] Destination: /home/yamen/Projects/Technocolabs/mp3/Blinding Lights - The Weeknd.mp3
# [download] 100% of 3.91MiB in 00:01 at 2.56MiB/s
# [download] Finished downloading playlist: Blinding Lights - The Weeknd
# [download] Downloading playlist: Good 4 U - Olivia Rodrigo
# [youtube:search] query "Good 4 U - Olivia Rodrigo": Downloading web client config
# [youtube:search] query "Good 4 U - Olivia Rodrigo" page 1: Downloading API JSON
# ...

# %%
import os
from requests import get
from yt_dlp import YoutubeDL

filename2=[]
def search1(arg , loc):
  # In this search(), I downloaded all popular and unpopular songs in an single folder called mp3
  YDL_OPTIONS = {'outtmpl': f"{loc}{arg}"+'.mp3','format' : 'bestaudio/best', 'noplaylist' : 'True'}
  with YoutubeDL(YDL_OPTIONS) as ydl:
    try:
      get(arg)
    except:
      song2 =   ydl.extract_info(f"ytsearch:{arg}", download=True)['entries'][0]
    else:
      song2 =   ydl.extract_info(arg, download=True)

  newpath1 = f"{arg}"+'.mp3'
  
  #newpath = f"{type}/{song['title']}.mp3"
  if os.path.isfile(newpath1):
    pass
  else:
    filename2.append(newpath1)
  
  return filename2, song2

titles = (dataset.Title + " - " + dataset.Artist).tolist()
# Here I'm Passing songs title and artists name as a title to the above search()
for i,title in enumerate(titles):
  if i <= 402:
    filename2, song2 = search1(title, '/home/yamen/Projects/Technocolabs/sample_data/popular/')
    i+=1
  elif i > 402:
    filename2, song2 = search1(title,   '/home/yamen/Projects/Technocolabs/sample_data/unpopular/')
    i+=1
  elif i == 809:
    break
# Out:
# [download] Downloading playlist: Blinding Lights - The Weeknd
# [youtube:search] query "Blinding Lights - The Weeknd": Downloading web client config
# [youtube:search] query "Blinding Lights - The Weeknd" page 1: Downloading API JSON
# [youtube:search] Playlist Blinding Lights - The Weeknd: Downloading 1 videos of 1
# [download] Downloading video 1 of 1
# [youtube] 4NRXx6U8ABQ: Downloading webpage
# [youtube] 4NRXx6U8ABQ: Downloading android player API JSON
# [info] 4NRXx6U8ABQ: Downloading 1 format(s): 251
# [download] Destination: /home/yamen/Projects/Technocolabs/sample_data/popular/Blinding Lights - The Weeknd.mp3
# [download] 100% of 3.91MiB in 00:01 at 2.54MiB/s
# [download] Finished downloading playlist: Blinding Lights - The Weeknd
# [download] Downloading playlist: Good 4 U - Olivia Rodrigo
# [youtube:search] query "Good 4 U - Olivia Rodrigo": Downloading web client config
# [youtube:search] query "Good 4 U - Olivia Rodrigo" page 1: Downloading API JSON
# ...

# %%
#print(filename2)
path = []
for i,files in enumerate(filename2):
  # Categorizing Popular $ Unpopular Songs In Different Folders
  if i <= 402 : # For Popualr Songs
    new = f'/home/yamen/Projects/Technocolabs/sample_data/popular/{files}'
    path.append(new)
    i += 1 
  elif i > 402: # For Unpopular Songs
    new = f'/home/yamen/Projects/Technocolabs/sample_data/unpopular/{files}'
    path.append(new)
    i +=1
  if i == 809:
    break

# %%
print(path)
# Out:
# ['/home/yamen/Projects/Technocolabs/sample_data/popular/Blinding Lights - The Weeknd.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Good 4 U - Olivia Rodrigo.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Drivers License - Olivia Rodrigo.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Montero (Call Me By Your Name) - Lil Nas X.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Butter - BTS.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Deja Vu - Olivia Rodrigo.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Positions - Ariana Grande.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Bad Habits - Ed Sheeran.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Forever After All - Luke Combs.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/What You Know Bout Love - Pop Smoke.mp3', '/home/yamen/Projects/Technocolabs/sample_data/popular/Therefore I Am - Billie Eilish.mp3', '/home/ya
# ...

# %%
df = pd.DataFrame(dataset)

df2 = pd.DataFrame({'Path':path})

# %%
new = pd.concat((df,df2), axis = 1)
new
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 823    Gwen Stefani                       Luxurious      0
# 824         Rihanna    If It's Lovin' That You Want      0
# 825       Lil Wayne                         Fireman      0
# 826     Alicia Keys                     Unbreakable      0
# 827   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path
# 0    /home/yamen/Projects/Technocolabs/sample_data/...
# 1    /home/yamen/Projects/Technocolabs/sample_data/...
# 2    /home/yamen/Projects/Technocolabs/sample_data/...
# ...

# %%
new.to_csv('DownloadSongs3.csv', index=False)

# %%
new_data = pd.read_csv('/home/yamen/Projects/Technocolabs/DownloadSongs3.csv')
new_data
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 823    Gwen Stefani                       Luxurious      0
# 824         Rihanna    If It's Lovin' That You Want      0
# 825       Lil Wayne                         Fireman      0
# 826     Alicia Keys                     Unbreakable      0
# 827   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path
# 0    /home/yamen/Projects/Technocolabs/sample_data/...
# 1    /home/yamen/Projects/Technocolabs/sample_data/...
# 2    /home/yamen/Projects/Technocolabs/sample_data/...
# ...

# %%
dataset = pd.read_csv('/home/yamen/Projects/Technocolabs/DownloadSongs3.csv')
dataset
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 823    Gwen Stefani                       Luxurious      0
# 824         Rihanna    If It's Lovin' That You Want      0
# 825       Lil Wayne                         Fireman      0
# 826     Alicia Keys                     Unbreakable      0
# 827   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path
# 0    /home/yamen/Projects/Technocolabs/sample_data/...
# 1    /home/yamen/Projects/Technocolabs/sample_data/...
# 2    /home/yamen/Projects/Technocolabs/sample_data/...
# ...

# %%
dataset = pd.read_csv('/home/yamen/Projects/Technocolabs/DownloadSongs3.csv')
paths = list(dataset['Path'])
titles = list(dataset['Title'])
data=[]

# %%
location=[]
chorus_path=[]
def extract_chorus(path, main):
  newpath = main
  for index in enumerate(newpath):
    if os.path.isfile(newpath):
      pass
    else:
      location.append(index)
      chorus_path.append(newpath)  
  chorus = find_and_output_chorus(path, newpath, 15)
  if chorus == None:
    return None
  else:
    return newpath , chorus_path

# %%
#for those 16 audio files that failed to detect 15 seconds repeated choruses
#I reduced search duration to 10 seconds for those audio files
import warnings
import os
warnings.filterwarnings('ignore')
from pychorus import find_and_output_chorus
location=[]
chorus_path=[]
def extract_10sec_chorus(path, main):
  
  #song_name = path.split('/', 2)[1].split('.')[0]
  #newpath = main + '/' + song_name + '.wav'
  newpath = main
  for index in enumerate(newpath):
    if os.path.isfile(newpath):
      pass
    else:
      location.append(index)
      chorus_path.append(newpath)  
  #chorus = find_and_output_chorus(path, newpath, 10)
  chorus = find_and_output_chorus(path, newpath, 5)
  if chorus == None:
    return None
  else:
    return newpath , chorus_path

# %%
new_main = []
i=0
# index of failed 15sce chorus and trying 10sec search duration
failed = [128,174,439,493,504,588,628,634,662,679,695,708,714,722,772,806]
# index of failed 10sec chorus and trying 8sec search duration
failed1 = [439,493,695,714]
for i,file in enumerate(paths):
  #for n in failed:
  #for n in failed1:
     #if i == 439 : #applied 6sec for the audio file in this index
      #print ()
      mp3_folder = f"/home/yamen/Projects/Technocolabs/mp3/{file}"
     main = f"/home/yamen/Projects/Technocolabs/Chorus/{file}.wav"
      #extract_10sec_chorus(mp3_folder, main)
      #extract_10sec_chorus(mp3_folder, main)
      new_main.append(main)

# %%
print(new_main)

# %%
df = pd.DataFrame(new_data)
df
# Remove columns by index
# df.drop(df.columns[[4, 5, 6]], axis = 1, inplace = True)
# df
df2 = pd.DataFrame({'Chorus_Path':new_main})
df2
# Out:
#                                            Chorus_Path
# 0    /home/yamen/Projects/Technocolabs/Chorus//home...
# 1    /home/yamen/Projects/Technocolabs/Chorus//home...
# 2    /home/yamen/Projects/Technocolabs/Chorus//home...
# 3    /home/yamen/Projects/Technocolabs/Chorus//home...
# 4    /home/yamen/Projects/Technocolabs/Chorus//home...
# ..                                                 ...
# 823   /home/yamen/Projects/Technocolabs/Chorus/nan.wav
# 824   /home/yamen/Projects/Technocolabs/Chorus/nan.wav
# 825   /home/yamen/Projects/Technocolabs/Chorus/nan.wav
# 826   /home/yamen/Projects/Technocolabs/Chorus/nan.wav
# 827   /home/yamen/Projects/Technocolabs/Chorus/nan.wav
#
# [828 rows x 1 columns]

# %%
 new = pd.concat((df,df2), axis = 1)
 new
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 823    Gwen Stefani                       Luxurious      0
# 824         Rihanna    If It's Lovin' That You Want      0
# 825       Lil Wayne                         Fireman      0
# 826     Alicia Keys                     Unbreakable      0
# 827   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path  \
# 0    /home/yamen/Projects/Technocolabs/sample_data/...
# 1    /home/yamen/Projects/Technocolabs/sample_data/...
# 2    /home/yamen/Projects/Technocolabs/sample_data/...
# ...

# %%
#new.to_csv('ExtractedChoruses.csv', index=False)
new.to_csv('ExtractedChoruses1.csv', index=False)

# %%
pwd = os.getcwd()
data_path = os.path.join(pwd,'ExtractedChoruses.csv')
data = pd.read_csv(data_path)
df = data.copy()

# %%
df[df['Path'].isna()] #check for null paths
# Out:
#                Artist                         Title  Label Path  \
# 809  Carrie Underwood                        Wasted      0  NaN
# 810              T.I.                      Top Back      0  NaN
# 811          The Fray                Look After You      0  NaN
# 812     Rascal Flatts                         Stand      0  NaN
# 813    Jonas Brothers                     Year 3000      0  NaN
# 814     Rascal Flatts                       My Wish      0  NaN
# 815      Taylor Swift                    Tim McGraw      0  NaN
# 816          The Fray      Happy Xmas (War Is Over)      0  NaN
# 817     Mary J. Blige               Take Me As I Am      0  NaN
# 818           Beyonce                        Listen      0  NaN
# 819           Beyonce                Ring The Alarm      0  NaN
# 820     Rascal Flatts                Me And My Gang      0  NaN
# 821  Carrie Underwood   Don't Forget To Remember Me      0  NaN
# 822      Gwen Stefani                         Crash      0  NaN
# ...

# %%
full_songs_path = list(df['Path']) 
chorus_extract_path = '/home/yamen/Projects/Technocolabs/Extract_Chorus' # path to save extracted chorus
extracted_songs = [basename.replace('.wav','') for basename in os.listdir(chorus_extract_path)] # basename/ song name of already extracted song to avoid repitition in chorus extraction

# %%
not_extracted = [] # list to track not extracted choruses

# %%
def extract_chorus(path_list, output_path):
    for path in path_list:
        basename = os.path.basename(str(path)).replace('.mp3', '')
        save_path = f'{output_path}/{basename}.wav' # output path as .wav extension 
        if basename in extracted_songs:
            print('song already exists')
        else:
            chorus = find_and_output_chorus(str(path), str(save_path), 15)
            if chorus == None:
                not_extracted.append(basename)

# %%
extract_chorus(full_songs_path,chorus_extract_path) #extract all choruses
# Out:
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# song already exists
# ...

# %%
len(not_extracted) # check total number of not extracted songs
# Out:
# 14

# %%
extracted_song_basename = [song.replace('.wav','') for song in os.listdir('Extract_Chorus')] # get extracteds songs basename
extracted_song_list = [] # list for songs from table present in successful extraction list 
for song in df['Path']:
    basename = os.path.basename(str(song)).replace('.mp3','')
    if  basename in extracted_song_basename:
        extracted_song_list.append(f'Extract_Chorus/{basename}.wav') # append successfuly extracted songs to list
    else:
        extracted_song_list.append('n/a') # append not available if extracted song does not exist

# %%
len(extracted_song_list)
# Out:
# 828

# %%
df = df.assign(extracted_chorus_path=extracted_song_list) # add new exteacted chorus paths to data table

# %%
df
# Out:
#              Artist                           Title  Label  \
# 0        The Weeknd                 Blinding Lights      1
# 1    Olivia Rodrigo                        Good 4 U      1
# 2    Olivia Rodrigo                 Drivers License      1
# 3         Lil Nas X  Montero (Call Me By Your Name)      1
# 4               BTS                          Butter      1
# ..              ...                             ...    ...
# 823    Gwen Stefani                       Luxurious      0
# 824         Rihanna    If It's Lovin' That You Want      0
# 825       Lil Wayne                         Fireman      0
# 826     Alicia Keys                     Unbreakable      0
# 827   Rascal Flatts                 Skin (Sarabeth)      0
#
#                                                   Path  \
# 0    /home/yamen/Projects/Technocolabs/sample_data/...
# 1    /home/yamen/Projects/Technocolabs/sample_data/...
# 2    /home/yamen/Projects/Technocolabs/sample_data/...
# ...

# %%
df[df['extracted_chorus_path']=='n/a'] # check for non available extracts path from list of chorus path
# Out:
#                Artist                               Title  Label  \
# 128      XXXTENTACION                         Look At Me!      1
# 174         Sam Smith                         Lay Me Down      1
# 429     Justin Bieber                              2 Much      0
# 512        The Weeknd                   Until I Bleed Out      0
# 523           Cardi B                               Press      0
# 647  The Chainsmokers                             #SELFIE      0
# 653            Eminem                             Rap God      0
# 681     One Direction  One Way Or Another (Teenage Kicks)      0
# 698           Beyonce                         Love On Top      0
# 714          Coldplay       Every Teardrop Is A Waterfall      0
# 727          Coldplay                    Christmas Lights      0
# 733        Kanye West                               POWER      0
# 741     Mary J. Blige                                I Am      0
# ...

# %%
#save table to csv file 
df.to_csv('extracted_chorus_incomplete.csv', index=False) # dataset with incomplete extracted choruses

# %%
data1 = pd.read_csv('extracted_chorus_incomplete.csv')
data1.isna().sum() # get total number of non available extracted paths
# Out:
# Artist                    0
# Title                     0
# Label                     0
# Path                     19
# Chorus_Path               0
# extracted_chorus_path    33
# dtype: int64

# %%
data1 = data1.dropna() # drop rows with non available extract path 
data1.isna().sum()
# Out:
# Artist                   0
# Title                    0
# Label                    0
# Path                     0
# Chorus_Path              0
# extracted_chorus_path    0
# dtype: int64

# %%
#save table to csv file 
data1.to_csv('extracted_chorus.csv', index=False)
